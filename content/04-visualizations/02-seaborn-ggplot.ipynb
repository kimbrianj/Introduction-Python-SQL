# %%
# Start (as usual) by loading libraries
import numpy as np
import pandas as pd
import matplotlib as mplib
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style()

# %% [markdown]
# # Other Plotting Libraries
#
# While `matplotlib` can be very useful for creating graphs, it can be easy to get bogged down in all of the intricacies of customizing everything you want to do. In this section, we introduce a

# %% [markdown]
# ## Seaborn
#
# Seaborn is a package built on top of `matplotlib` that is meant to make some of the difficult tasks easier to do.

# %%
df_2015 = pd.read_csv('https://lehd.ces.census.gov/data/lodes/LODES7/md/wac/md_wac_S000_JT00_2015.csv.gz', compression = 'gzip')

# %%
sns.displot(df_2015, x = 'CA01', stat="density", discrete=True).set(xlim=(0,100))

# %% [markdown]
# ## ggplot
#
# For people familiar with R and ggplot2, using `ggplot` might be preferable because it uses a lot of the same syntax as the R version.

# %%
from plotnine import *

# %%
ggplot(df_2015) + aes(x = 'CA01') + geom_histogram(bins = 20) + labs(
# Out:
# <ggplot: (441028627)>
